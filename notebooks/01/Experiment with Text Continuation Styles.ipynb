# %% [markdown]
# <a href="https://colab.research.google.com/github/dannys0n/CS394-MyRepo/blob/main/notebooks/01/GPT-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 1 Notebook
#
# <a target="_blank" href="https://colab.research.google.com/github/simonguest/CS-394/blob/main/src/01/notebooks/GPT-2.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
# <a target="_blank" href="https://github.com/simonguest/CS-394/raw/refs/heads/main/src/01/notebooks/GPT-2.ipynb">
#   <img src="https://img.shields.io/badge/Download_.ipynb-blue" alt="Download .ipynb"/>
# </a>

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# Load pre-trained GPT-2 model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

# Set pad token
tokenizer.pad_token = tokenizer.eos_token

# %%
import torch

def autocomplete(prompt, max_length=50, temperature=0.1, top_k=1, top_p=0.9):
    # Encode the prompt with attention mask
    inputs = tokenizer(prompt, return_tensors="pt")

    # Generate continuation
    with torch.no_grad():
        output = model.generate(
            inputs['input_ids'],
            attention_mask=inputs['attention_mask'],
            max_length=max_length,
            temperature=temperature,
            top_k=top_k,
            top_p=top_p,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id
        )

    # Decode and return the generated text
    generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
    return generated_text

# %%
prompt = "Mary had a little lamb"
completion = autocomplete(prompt, max_length=80)
print(completion)

# %%
prompts = [
    "I flipped a coin, and it caused",
    "The most common language in my world is",
    "Once upon a time, in 500BC. ",
]

for prompt in prompts:
    print(f"\nPrompt: {prompt}")
    print("-" * 50)
    completion = autocomplete(prompt, max_length=80)
    print(f"Output: {completion}\n")

# %% [markdown]
# My Results
# --------------------------------------------------
# Changing the temperature and top-k created some results I expected. such as temperature=0.1, top_k=1 making my prompts output deterministic and create more literal statemements, rather than narrative. However, it did suffer a lot from repetition.
#
# Setting the temperature=1, top_k=50 made more varied, created more varied and creative completions. It also seemed much less prone to repetition

# %% [markdown]
# max_length=50, temperature=0.1, top_k=1, top_p=0.9
#
# Prompt: I flipped a coin, and it caused
# --------------------------------------------------
# Output: I flipped a coin, and it caused a coin flip.
#
# The coin flip was a common occurrence in the early days of the Internet. It was a way to make money, and it was a way to make money for the people who were using it.
#
# The coin flip was a common occurrence in the early days of the Internet. It was a way to make money, and it
#
#
# Prompt: The most common language in my world is
# --------------------------------------------------
# Output: The most common language in my world is "I'm a man."
#
# I'm a man.
#
# I'm a man.
#
# I'm a man.
#
# I'm a man.
#
# I'm a man.
#
# I'm a man.
#
# I'm a man.
#
# I'm a man.
#
# I'm a man.
#
# I
#
#
# Prompt: Once upon a time, in 500BC.
# --------------------------------------------------
# Output: Once upon a time, in 500BC.  The first of the three kings of the world, the king of the world, was a man of great wealth and power.  He was a man of great wealth and power.  He was a man of great wealth and power.  He was a man of great wealth and power.  He was a man of great

# %% [markdown]
# max_length=50, temperature=1, top_k=50, top_p=0.9
#
# Prompt: I flipped a coin, and it caused
# --------------------------------------------------
# Output: I flipped a coin, and it caused the coin to go red, with my hand on a white tile, and it's now red.
#
# I turn on a light, and a blue one.
#
# It goes down a staircase. The player is then in control of this one tile tile, and their opponents are then in control of this one tile tile. The player flips a coin,
#
#
# Prompt: The most common language in my world is
# --------------------------------------------------
# Output: The most common language in my world is "migrating to the U.S., using the government's bureaucracy and to the U.S. as a way to move freely." But that's not the whole story. The immigration program, it turns out, is a sham, designed to keep illegal immigrants from moving. That's why it has become so common.
#
# The government is also
#
#
# Prompt: Once upon a time, in 500BC.
# --------------------------------------------------
# Output: Once upon a time, in 500BC.  They were the people that were standing there on a bridge on the north side of this river, where there were no men. And we were on the other side of the river, on the left, as well as on the right. And there were six boats, three of which were made for us by this boat, and three of
